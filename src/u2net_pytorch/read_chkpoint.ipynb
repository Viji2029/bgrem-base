# %%
## Importing libraries
import torch
import pytorch_lightning as pl
from train_lightning import U2NET_full, U2NetLightning

# %%
checkpoint_path = "./outputs/checkpoints/2023_09_06_09_15_50/u2net_train_loss_epoch=0001_train_loss=0.00.ckpt"
ckpt = torch.load(checkpoint_path, map_location=torch.device("cpu"))
u2net = U2NET_full()
    # u2net = U2NET_lite()
pl_model = U2NetLightning({}, u2net)

# %%
u2net
# Out:
# U2NET(
#   (downsample): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (stage1): RSU(
#     (rebnconvin): REBNCONV(
#       (conv_s1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn_s1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu_s1): ReLU(inplace=True)
#     )
#     (downsample): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (rebnconv1): REBNCONV(
#       (conv_s1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn_s1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu_s1): ReLU(inplace=True)
#     )
#     (rebnconv1d): REBNCONV(
#       (conv_s1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn_s1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu_s1): ReLU(inplace=True)
#     )
# ...

# %%
parameters = {}
for name, param in ckpt["state_dict"].items():
    parameters[name] = param
    print(name)
# Out:
# model.stage1.rebnconvin.conv_s1.weight
# model.stage1.rebnconvin.conv_s1.bias
# model.stage1.rebnconvin.bn_s1.weight
# model.stage1.rebnconvin.bn_s1.bias
# model.stage1.rebnconvin.bn_s1.running_mean
# model.stage1.rebnconvin.bn_s1.running_var
# model.stage1.rebnconvin.bn_s1.num_batches_tracked
# model.stage1.rebnconv1.conv_s1.weight
# model.stage1.rebnconv1.conv_s1.bias
# model.stage1.rebnconv1.bn_s1.weight
# model.stage1.rebnconv1.bn_s1.bias
# model.stage1.rebnconv1.bn_s1.running_mean
# model.stage1.rebnconv1.bn_s1.running_var
# model.stage1.rebnconv1.bn_s1.num_batches_tracked
# model.stage1.rebnconv1d.conv_s1.weight
# model.stage1.rebnconv1d.conv_s1.bias
# model.stage1.rebnconv1d.bn_s1.weight
# model.stage1.rebnconv1d.bn_s1.bias
# model.stage1.rebnconv1d.bn_s1.running_mean
# model.stage1.rebnconv1d.bn_s1.running_var
# model.stage1.rebnconv1d.bn_s1.num_batches_tracked
# model.stage1.rebnconv2.conv_s1.weight
# model.stage1.rebnconv2.conv_s1.bias
# model.stage1.rebnconv2.bn_s1.weight
# ...

# %%
print("Total parameters:",len(parameters))
# Out:
# Total parameters: 798
